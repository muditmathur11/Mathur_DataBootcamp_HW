# %% [markdown]
# # WeatherPy
# ----
#
# #### Mudit's Analysis
# * 1) The most distinguishable observation comes from the City Latitude vs. Max Temperature Graph. The closer that a city gets to the equator, the higher the max temperature. However the peak temperatures from the data set seem to occur more along 20 degrees latitude line instead of the equator, due to the tilt of the earth's axis in relation to the Sun.
#
# * 2) City Latitude vs Humidity also shows that cities closer to the equator tend to have higher humidities. This correlation is apparent but not as strong as between City Latitude and Temperature.
#
# * 3) There seems to be no discernible correlation between City Latitude to Wind Speed and Cloudiness.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=

# %%
# Create empty lists to append API calls 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Initialize record variable to 1 
record = 1

# %%
# Beginning print statement 
print(f'Beginning of Data Retrieval\n------------------------------------')

# Loop through the list of cities and perform a request for data on each
for city in cities:
    # Use try statement to keep appending even if city has missing value
    try:
        response = requests.get(f'{query_url}{city}').json()
        lat.append(response['coord']['lat'])
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        
        # Replace spaces in city name URL retrieved so it is not broken
        city_record = city.replace(" ", "%20") 
        
        # Print the output
        print(f'Processing Record {record} | {city}')
        print(f'{query_url}{city_record}')
        
        # Increase record by 1 
        record += 1
        
        # Pause for loop for 1 second so API rate is not exceeded
        time.sleep(1)
        
    # Skip to next city if missing data
    except:
        print("City not found. Skipping ... ")
# Out:
# Beginning of Data Retrieval
# ------------------------------------
# Processing Record 1 | tekeli
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tekeli
# City not found. Skipping ...
# Processing Record 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=georgetown
# Processing Record 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=longyearbyen
# Processing Record 4 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hermanus
# Processing Record 5 | harboore
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=harboore
# Processing Record 6 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=provideniya
# Processing Record 7 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=barrow
# Processing Record 8 | okato
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=okato
# Processing Record 9 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=katsuura
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 10 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ponta%20do%20sol
# Processing Record 11 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=jamestown
# Processing Record 12 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=yellowknife
# Processing Record 13 | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ahipara
# Processing Record 14 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=albany
# Processing Record 15 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ushuaia
# Processing Record 16 | zwedru
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=zwedru
# Processing Record 17 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=thompson
# Processing Record 18 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=bluff
# Processing Record 19 | portel
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=portel
# Processing Record 20 | alyangula
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=alyangula
# Processing Record 21 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=butaritari
# Processing Record 22 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=bredasdorp
# Processing Record 23 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pisco
# City not found. Skipping ...
# Processing Record 24 | starkville
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=starkville
# Processing Record 25 | bendigo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=bendigo
# Processing Record 26 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=chuy
# City not found. Skipping ...
# Processing Record 27 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=klaksvik
# Processing Record 28 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mataura
# Processing Record 29 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=castro
# City not found. Skipping ...
# Processing Record 30 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lagoa
# Processing Record 31 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=berlevag
# Processing Record 32 | valenca do piaui
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=valenca%20do%20piaui
# Processing Record 33 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=cidreira
# Processing Record 34 | mudgee
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mudgee
# City not found. Skipping ...
# Processing Record 35 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=busselton
# Processing Record 36 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=la%20ronge
# Processing Record 37 | hoskote
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hoskote
# Processing Record 38 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=airai
# Processing Record 39 | rock springs
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=rock%20springs
# Processing Record 40 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=faanui
# Processing Record 41 | sahuaripa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sahuaripa
# Processing Record 42 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20patricio
# Processing Record 43 | rancho veloz
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=rancho%20veloz
# Processing Record 44 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=rikitea
# City not found. Skipping ...
# Processing Record 45 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saint-pierre
# Processing Record 46 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=carnarvon
# Processing Record 47 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kattivakkam
# Processing Record 48 | keta
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=keta
# City not found. Skipping ...
# Processing Record 49 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pevek
# Processing Record 50 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hilo
# Processing Record 51 | troutdale
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=troutdale
# City not found. Skipping ...
# Processing Record 52 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=upernavik
# Processing Record 53 | zheleznodorozhnyy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=zheleznodorozhnyy
# Processing Record 54 | venice
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=venice
# City not found. Skipping ...
# Processing Record 55 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kapaa
# Processing Record 56 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=geraldton
# Processing Record 57 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=port%20alfred
# Processing Record 58 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hobart
# Processing Record 59 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=punta%20arenas
# Processing Record 60 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=belyy%20yar
# City not found. Skipping ...
# Processing Record 61 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=bethel
# Processing Record 62 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kahului
# Processing Record 63 | kaili
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kaili
# Processing Record 64 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=muros
# Processing Record 65 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=comodoro%20rivadavia
# Processing Record 66 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hithadhoo
# Processing Record 67 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=isangel
# Processing Record 68 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=qaanaaq
# Processing Record 69 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saint-georges
# Processing Record 70 | paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=paamiut
# Processing Record 71 | kalynivka
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kalynivka
# Processing Record 72 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=port%20lincoln
# Processing Record 73 | iida
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=iida
# Processing Record 74 | daru
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=daru
# Processing Record 75 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=yulara
# Processing Record 76 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=yar-sale
# Processing Record 77 | clearlake
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=clearlake
# Processing Record 78 | khalkhal
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=khalkhal
# Processing Record 79 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=east%20london
# Processing Record 80 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=cape%20town
# Processing Record 81 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=nikolskoye
# Processing Record 82 | villa de san francisco
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=villa%20de%20san%20francisco
# City not found. Skipping ...
# Processing Record 83 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mahebourg
# Processing Record 84 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=vaini
# Processing Record 85 | palmer
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=palmer
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 86 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=port%20elizabeth
# Processing Record 87 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=new%20norfolk
# Processing Record 88 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lebu
# Processing Record 89 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=cabo%20san%20lucas
# Processing Record 90 | chimore
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=chimore
# Processing Record 91 | dolores
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=dolores
# Processing Record 92 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=necochea
# Processing Record 93 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=arraial%20do%20cabo
# Processing Record 94 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=port%20blair
# Processing Record 95 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=chokurdakh
# Processing Record 96 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=caravelas
# Processing Record 97 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saint-philippe
# Processing Record 98 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=clyde%20river
# Processing Record 99 | charters towers
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=charters%20towers
# Processing Record 100 | pastos bons
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pastos%20bons
# Processing Record 101 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tuatapere
# Processing Record 102 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saint-louis
# Processing Record 103 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=fortuna
# Processing Record 104 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=atuona
# Processing Record 105 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sao%20filipe
# Processing Record 106 | axim
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=axim
# Processing Record 107 | along
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=along
# Processing Record 108 | kantunilkin
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kantunilkin
# Processing Record 109 | risor
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=risor
# Processing Record 110 | kinwat
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kinwat
# Processing Record 111 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sinnamary
# Processing Record 112 | atar
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=atar
# Processing Record 113 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lorengau
# Processing Record 114 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sitka
# Processing Record 115 | san carlos
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20carlos
# Processing Record 116 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=dikson
# Processing Record 117 | north platte
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=north%20platte
# Processing Record 118 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=batemans%20bay
# Processing Record 119 | oum hadjer
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=oum%20hadjer
# City not found. Skipping ...
# Processing Record 120 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=esperance
# Processing Record 121 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kavieng
# Processing Record 122 | teya
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=teya
# Processing Record 123 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=narsaq
# Processing Record 124 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=komsomolskiy
# City not found. Skipping ...
# Processing Record 125 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=souillac
# Processing Record 126 | morros
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=morros
# Processing Record 127 | inirida
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=inirida
# Processing Record 128 | todos santos
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=todos%20santos
# Processing Record 129 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=wahiawa
# Processing Record 130 | yanacancha
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=yanacancha
# Processing Record 131 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saskylakh
# Processing Record 132 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=acapulco
# Processing Record 133 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kysyl-syr
# Processing Record 134 | aykhal
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=aykhal
# Processing Record 135 | havoysund
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=havoysund
# Processing Record 136 | benavente
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=benavente
# City not found. Skipping ...
# Processing Record 137 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mar%20del%20plata
# Processing Record 138 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=bambous%20virieux
# Processing Record 139 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ribeira%20grande
# Processing Record 140 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=torbay
# Processing Record 141 | kungurtug
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kungurtug
# Processing Record 142 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=khatanga
# Processing Record 143 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=constitucion
# Processing Record 144 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sur
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 145 | devon
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=devon
# City not found. Skipping ...
# Processing Record 146 | waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=waipawa
# Processing Record 147 | wexford
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=wexford
# City not found. Skipping ...
# Processing Record 148 | xuddur
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=xuddur
# City not found. Skipping ...
# Processing Record 149 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saint%20george
# Processing Record 150 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kaitangata
# Processing Record 151 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sao%20jose%20da%20coroa%20grande
# Processing Record 152 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=gushikawa
# Processing Record 153 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=solnechnyy
# Processing Record 154 | griffith
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=griffith
# Processing Record 155 | whitehaven
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=whitehaven
# Processing Record 156 | singaraja
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=singaraja
# Processing Record 157 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hasaki
# City not found. Skipping ...
# Processing Record 158 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mogadishu
# Processing Record 159 | tsumeb
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tsumeb
# Processing Record 160 | simbahan
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=simbahan
# City not found. Skipping ...
# Processing Record 161 | portage
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=portage
# Processing Record 162 | galeana
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=galeana
# Processing Record 163 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saint%20anthony
# Processing Record 164 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hofn
# Processing Record 165 | san jose
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20jose
# Processing Record 166 | pringsewu
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pringsewu
# Processing Record 167 | paka
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=paka
# Processing Record 168 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ucluelet
# Processing Record 169 | puerto quijarro
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=puerto%20quijarro
# Processing Record 170 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=verkhnyaya%20inta
# Processing Record 171 | sabang
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sabang
# Processing Record 172 | padang
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=padang
# Processing Record 173 | erdenet
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=erdenet
# Processing Record 174 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=nome
# Processing Record 175 | coronel vivida
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=coronel%20vivida
# Processing Record 176 | beyneu
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=beyneu
# Processing Record 177 | pospelikha
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pospelikha
# Processing Record 178 | texarkana
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=texarkana
# Processing Record 179 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=coihaique
# Processing Record 180 | kaeo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kaeo
# Processing Record 181 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=cayenne
# Processing Record 182 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=portland
# Processing Record 183 | havelock
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=havelock
# Processing Record 184 | catalca
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=catalca
# Processing Record 185 | pasighat
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pasighat
# Processing Record 186 | myitkyina
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=myitkyina
# City not found. Skipping ...
# Processing Record 187 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=talnakh
# Processing Record 188 | el burrion
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=el%20burrion
# Processing Record 189 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saldanha
# City not found. Skipping ...
# Processing Record 190 | calatayud
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=calatayud
# Processing Record 191 | kokstad
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kokstad
# Processing Record 192 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=luderitz
# Processing Record 193 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=avarua
# Processing Record 194 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=puerto%20ayora
# Processing Record 195 | black river
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=black%20river
# Processing Record 196 | letlhakane
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=letlhakane
# City not found. Skipping ...
# Processing Record 197 | aguas formosas
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=aguas%20formosas
# Processing Record 198 | sao joaquim
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sao%20joaquim
# Processing Record 199 | tooele
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tooele
# Processing Record 200 | arrifes
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=arrifes
# Processing Record 201 | maumere
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=maumere
# Processing Record 202 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kodiak
# Processing Record 203 | san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20quintin
# Processing Record 204 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=batagay-alyta
# Processing Record 205 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ixtapa
# Processing Record 206 | seymchan
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=seymchan
# Processing Record 207 | tromso
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tromso
# Processing Record 208 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=husavik
# Processing Record 209 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=te%20anau
# Processing Record 210 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=port%20hardy
# Processing Record 211 | batagay
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=batagay
# City not found. Skipping ...
# Processing Record 212 | sai buri
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sai%20buri
# Processing Record 213 | plouzane
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=plouzane
# Processing Record 214 | vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=vanimo
# Processing Record 215 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ngunguru
# Processing Record 216 | el progreso
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=el%20progreso
# Processing Record 217 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=okhotsk
# Processing Record 218 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ilulissat
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 219 | ullapool
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ullapool
# Processing Record 220 | vallenar
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=vallenar
# Processing Record 221 | fare
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=fare
# City not found. Skipping ...
# Processing Record 222 | shostka
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=shostka
# Processing Record 223 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mount%20gambier
# Processing Record 224 | pindiga
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pindiga
# Processing Record 225 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20policarpo
# Processing Record 226 | locri
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=locri
# Processing Record 227 | saraland
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saraland
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 228 | huangzhai
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=huangzhai
# Processing Record 229 | berberati
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=berberati
# Processing Record 230 | rzhaksa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=rzhaksa
# Processing Record 231 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mehamn
# Processing Record 232 | arman
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=arman
# Processing Record 233 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ishigaki
# Processing Record 234 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=guerrero%20negro
# City not found. Skipping ...
# Processing Record 235 | avera
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=avera
# Processing Record 236 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=flinders
# Processing Record 237 | hyeres
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hyeres
# Processing Record 238 | christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=christchurch
# Processing Record 239 | northam
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=northam
# Processing Record 240 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=los%20llanos%20de%20aridane
# Processing Record 241 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=vila%20velha
# Processing Record 242 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=quatre%20cocos
# Processing Record 243 | pangody
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pangody
# Processing Record 244 | zanjan
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=zanjan
# City not found. Skipping ...
# Processing Record 245 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tuktoyaktuk
# Processing Record 246 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=namibe
# Processing Record 247 | menongue
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=menongue
# Processing Record 248 | labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=labuhan
# City not found. Skipping ...
# Processing Record 249 | duluth
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=duluth
# Processing Record 250 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=dingle
# Processing Record 251 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=codrington
# Processing Record 252 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tiksi
# Processing Record 253 | lima
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lima
# Processing Record 254 | moba
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=moba
# Processing Record 255 | devin
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=devin
# Processing Record 256 | oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=oktyabrskoye
# Processing Record 257 | zaqatala
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=zaqatala
# Processing Record 258 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pangnirtung
# Processing Record 259 | diffa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=diffa
# Processing Record 260 | balingasay
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=balingasay
# Processing Record 261 | jorochito
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=jorochito
# Processing Record 262 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lazaro%20cardenas
# Processing Record 263 | anchorage
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=anchorage
# Processing Record 264 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saint-augustin
# Processing Record 265 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ambilobe
# Processing Record 266 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ostrovnoy
# Processing Record 267 | dukat
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=dukat
# Processing Record 268 | tawau
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tawau
# Processing Record 269 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=bathsheba
# Processing Record 270 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=cockburn%20town
# Processing Record 271 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20cristobal
# Processing Record 272 | abu road
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=abu%20road
# Processing Record 273 | mayumba
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mayumba
# Processing Record 274 | lamar
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lamar
# Processing Record 275 | tateyama
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tateyama
# Processing Record 276 | binzhou
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=binzhou
# Processing Record 277 | kita
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kita
# Processing Record 278 | nsanje
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=nsanje
# Processing Record 279 | nazarovo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=nazarovo
# Processing Record 280 | baiquan
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=baiquan
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 281 | adra
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=adra
# Processing Record 282 | nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=nemuro
# Processing Record 283 | san pedro
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20pedro
# Processing Record 284 | kupang
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kupang
# City not found. Skipping ...
# Processing Record 285 | wuwei
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=wuwei
# City not found. Skipping ...
# Processing Record 286 | umbuzeiro
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=umbuzeiro
# City not found. Skipping ...
# Processing Record 287 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=qaqortoq
# Processing Record 288 | japura
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=japura
# Processing Record 289 | adrar
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=adrar
# Processing Record 290 | guilin
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=guilin
# Processing Record 291 | hovd
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hovd
# Processing Record 292 | san andres
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20andres
# Processing Record 293 | morrope
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=morrope
# Processing Record 294 | tual
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tual
# Processing Record 295 | tucuman
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tucuman
# Processing Record 296 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tasiilaq
# Processing Record 297 | sidi ali
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sidi%20ali
# Processing Record 298 | vidalia
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=vidalia
# Processing Record 299 | imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=imbituba
# Processing Record 300 | jand
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=jand
# Processing Record 301 | abdulino
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=abdulino
# Processing Record 302 | presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=presidencia%20roque%20saenz%20pena
# Processing Record 303 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hamilton
# Processing Record 304 | yemtsa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=yemtsa
# Processing Record 305 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=saint-joseph
# Processing Record 306 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=cherskiy
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 307 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=oranjemund
# Processing Record 308 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=iqaluit
# Processing Record 309 | damietta
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=damietta
# Processing Record 310 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=samarai
# Processing Record 311 | mount pleasant
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mount%20pleasant
# Processing Record 312 | wloclawek
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=wloclawek
# City not found. Skipping ...
# Processing Record 313 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=hami
# Processing Record 314 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=half%20moon%20bay
# Processing Record 315 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=port-gentil
# Processing Record 316 | khao wong
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=khao%20wong
# Processing Record 317 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=richards%20bay
# Processing Record 318 | rudnichnyy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=rudnichnyy
# Processing Record 319 | troitsko-pechorsk
# ...
# Processing Record 427 | eyl
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=eyl
# Processing Record 428 | lesnikovo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lesnikovo
# Processing Record 429 | shimanovsk
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=shimanovsk
# Processing Record 430 | bahia honda
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=bahia%20honda
# Processing Record 431 | sulangan
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sulangan
# Processing Record 432 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=abu%20dhabi
# Processing Record 433 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sisimiut
# Processing Record 434 | olga
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=olga
# City not found. Skipping ...
# Processing Record 435 | luwuk
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=luwuk
# Processing Record 436 | san luis
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20luis
# Processing Record 437 | slave lake
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=slave%20lake
# Processing Record 438 | warrnambool
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=warrnambool
# City not found. Skipping ...
# Processing Record 439 | soyo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=soyo
# Processing Record 440 | odienne
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=odienne
# Processing Record 441 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=thinadhoo
# Processing Record 442 | gualaquiza
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=gualaquiza
# Processing Record 443 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=turukhansk
# Processing Record 444 | khorol
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=khorol
# Processing Record 445 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ust-kuyga
# Processing Record 446 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=victoria
# Processing Record 447 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sungaipenuh
# Processing Record 448 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=broome
# Processing Record 449 | aurillac
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=aurillac
# City not found. Skipping ...
# Processing Record 450 | riohacha
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=riohacha
# Processing Record 451 | parabel
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=parabel
# Processing Record 452 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=port%20hawkesbury
# Processing Record 453 | zasosna
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=zasosna
# Processing Record 454 | jan kempdorp
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=jan%20kempdorp
# Processing Record 455 | warrington
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=warrington
# City not found. Skipping ...
# Processing Record 456 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=broken%20hill
# Processing Record 457 | ribas do rio pardo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ribas%20do%20rio%20pardo
# City not found. Skipping ...
# Processing Record 458 | mizdah
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mizdah
# Processing Record 459 | birjand
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=birjand
# Processing Record 460 | the valley
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=the%20valley
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 461 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=coquimbo
# Processing Record 462 | moshenskoye
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=moshenskoye
# Processing Record 463 | mantua
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mantua
# Processing Record 464 | zelezniki
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=zelezniki
# Processing Record 465 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=sola
# Processing Record 466 | tsabong
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=tsabong
# Processing Record 467 | atocha
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=atocha
# Processing Record 468 | comarapa
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=comarapa
# City not found. Skipping ...
# Processing Record 469 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=naze
# Processing Record 470 | oga
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=oga
# Processing Record 471 | maku
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=maku
# Processing Record 472 | vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=vilhena
# Processing Record 473 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=abu%20kamal
# Processing Record 474 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=beringovskiy
# Processing Record 475 | itoman
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=itoman
# Processing Record 476 | bay city
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=bay%20city
# City not found. Skipping ...
# Processing Record 477 | basco
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=basco
# Processing Record 478 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ketchikan
# Processing Record 479 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ancud
# Processing Record 480 | ondjiva
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ondjiva
# Processing Record 481 | ravar
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ravar
# Processing Record 482 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mnogovershinnyy
# Processing Record 483 | la rioja
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=la%20rioja
# Processing Record 484 | kjollefjord
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kjollefjord
# City not found. Skipping ...
# Processing Record 485 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=port%20macquarie
# Processing Record 486 | nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=nuuk
# Processing Record 487 | walcz
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=walcz
# Processing Record 488 | ukiah
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ukiah
# Processing Record 489 | baytown
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=baytown
# Processing Record 490 | pandan
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pandan
# Processing Record 491 | artigas
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=artigas
# Processing Record 492 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=nhulunbuy
# City not found. Skipping ...
# Processing Record 493 | villa union
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=villa%20union
# Processing Record 494 | kristiansund
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kristiansund
# Processing Record 495 | forotic
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=forotic
# Processing Record 496 | pundaguitan
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pundaguitan
# Processing Record 497 | chaiyaphum
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=chaiyaphum
# Processing Record 498 | xining
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=xining
# Processing Record 499 | de aar
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=de%20aar
# Processing Record 500 | gardner
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=gardner
# Processing Record 501 | pokhara
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pokhara
# Processing Record 502 | millerovo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=millerovo
# Processing Record 503 | victoria point
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=victoria%20point
# Processing Record 504 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lompoc
# Processing Record 505 | bolobo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=bolobo
# Processing Record 506 | high prairie
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=high%20prairie
# Processing Record 507 | ulundi
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=ulundi
# Processing Record 508 | palmares do sul
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=palmares%20do%20sul
# Processing Record 509 | charcas
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=charcas
# Processing Record 510 | gamba
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=gamba
# Processing Record 511 | pauini
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=pauini
# City not found. Skipping ...
# Processing Record 512 | demba
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=demba
# Processing Record 513 | jinchang
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=jinchang
# Processing Record 514 | kaabong
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=kaabong
# Processing Record 515 | mazagao
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mazagao
# City not found. Skipping ...
# Processing Record 516 | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mayo
# Processing Record 517 | juruti
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=juruti
# Processing Record 518 | lerwick
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lerwick
# City not found. Skipping ...
# Processing Record 519 | larreynaga
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=larreynaga
# Processing Record 520 | dunda
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=dunda
# Processing Record 521 | santa isabel
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=santa%20isabel
# Processing Record 522 | san javier
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=san%20javier
# Processing Record 523 | lake charles
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=lake%20charles
# Processing Record 524 | yumen
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=yumen
# Processing Record 525 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=gat
# City not found. Skipping ...
# Processing Record 526 | madimba
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=madimba
# City not found. Skipping ...
# Processing Record 527 | nyanguge
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=nyanguge
# Processing Record 528 | le port
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=le%20port
# Processing Record 529 | mezen
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=mezen
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 530 | itambacuri
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=itambacuri
# Processing Record 531 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=plettenberg%20bay
# Processing Record 532 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=a0844959dd699a5bc56c05d47925efae&units=imperial&q=margate

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary to hold the lists 
cities_summary = {
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

# Convert the dictionary to a Data Frame 
weather_data = pd.DataFrame(cities_summary)

# Count the values column
weather_data.count()
# Out:
# City          532
# Cloudiness    532
# Country       532
# Date          532
# Humidity      532
# Lat           532
# Lng           532
# Max Temp      532
# Wind Speed    532
# dtype: int64

# %%
# Export the data into a CSV 
weather_data.to_csv("../Data_CSV/weather_data.csv")

# Display data frame 
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0        Tekeli          54      KZ  1563660777        38  44.86  78.76
# 1    Georgetown          40      GY  1563660519        78   6.80 -58.16
# 2  Longyearbyen          75      NO  1563660475        87  78.22  15.63
# 3      Hermanus         100      ZA  1563660489        82 -34.42  19.24
# 4      Harboore          88      DK  1563660781        93  56.62   8.18
#
#    Max Temp  Wind Speed
# 0     70.36        4.59
# 1     82.40        9.17
# 2     42.80        8.05
# 3     46.99       11.01
# 4     63.00        3.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a scatter plot of Lattitude vs. Temperature
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolors="darkblue", s=20)

# Incorporate graph properties
plt.title(("City Latitude vs. Max Temperature (%s)" % time.strftime("%x")))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# Save the plot 
plt.savefig("../Plots/lat_temp.png")

# Display the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a scatter plot of Lattitude vs. Humidity 
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolors="darkblue", s=20)

# Incorporate graph properties
plt.title(("City Latitude vs. Humidity (%s)" % time.strftime("%x")))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the plot 
plt.savefig("../Plots/lat_humidity.png")

# Display the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot of Lattitude vs. Cloudiness 
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", edgecolors="darkblue", s=20)

# Incorporate graph properties
plt.title(("City Latitude vs. Cloudiness (%s)" % time.strftime("%x")))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the plot 
plt.savefig("../Plots/lat_cloudiness.png")

# Display the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot of Lattitude vs. Wind Speed 
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolors="darkblue", s=20)

# Incorporate graph properties
plt.title(("City Latitude vs. Wind Speed (%s)" % time.strftime("%x")))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

# Save the plot 
plt.savefig("../Plots/lat_wind.png")

# Display the plot
plt.show()
